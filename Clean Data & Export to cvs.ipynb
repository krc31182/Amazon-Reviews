# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
import re, string

# %% [markdown]
# # LOAD THE DATA IN

# %%
#read in csv file
df = pd.read_csv('Resources/US_Reviews.csv')

# %%
df.head(2)
# Out:
#    Retailer ID Retailer Name Retailer SKU           UPC Model Number  \
# 0            1    Amazon.com   B0735Q681B  7.544650e+11  70907205419
# 1            1    Amazon.com   B00WX0RJVS  8.858930e+11      2076438
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
#
#   Subcategory  Week ID Week Ending Review Date       Review ID  Review Stars  \
# 0     Condoms   202245  11/12/2022  11/12/2022  R3A94R1G39RSYD             5
# 1     Condoms   202245  11/12/2022  11/12/2022  R2MBHRRN9LP4VS             5
#
#   Is Verified Has Response                                        Review Text  \
# 0         yes           no   Pretty good rubbers. Great for pounding  and ...
# 1         yes           no   They are good  out of the whole box i did hav...
#
#       Review Title                                        Reviews Url  \
# 0    Good Rubbers   https://www.amazon.com/gp/customer-reviews/R3A...
# 1   They are good   https://www.amazon.com/gp/customer-reviews/R2M...
#
#                   Reviewer
# 0                 Fat Dabs
# 1  Roberto coronado medina

# %%
#rename headings
df.rename(columns={'Retailer ID': 'retailer_id', 'Retailer Name': 'retailer_name', 'Retailer SKU': 'retailer_sku', 'Week ID': 'week_id', 'Week Ending':'week_ending', 'Review Date':'review_date','Review ID':'review_id','Review Stars':'review_stars','Is Verified':'is_verified','Has Response':'has_response', 'Review Text':'review_text', 'Review Title':'review_title', 'Reviews Url':'reviews_url'}, inplace=True)
df.head(2)
# Out:
#    retailer_id retailer_name retailer_sku           UPC Model Number  \
# 0            1    Amazon.com   B0735Q681B  7.544650e+11  70907205419
# 1            1    Amazon.com   B00WX0RJVS  8.858930e+11      2076438
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
#
#   Subcategory  week_id week_ending review_date       review_id  review_stars  \
# 0     Condoms   202245  11/12/2022  11/12/2022  R3A94R1G39RSYD             5
# 1     Condoms   202245  11/12/2022  11/12/2022  R2MBHRRN9LP4VS             5
#
#   is_verified has_response                                        review_text  \
# 0         yes           no   Pretty good rubbers. Great for pounding  and ...
# 1         yes           no   They are good  out of the whole box i did hav...
#
#       review_title                                        reviews_url  \
# 0    Good Rubbers   https://www.amazon.com/gp/customer-reviews/R3A...
# 1   They are good   https://www.amazon.com/gp/customer-reviews/R2M...
#
#                   Reviewer
# 0                 Fat Dabs
# 1  Roberto coronado medina

# %%
#combine the review text and the review title
df['combined_text'] = df['review_text'] + ' ' + df['review_title']

#change is verfied to 1 or 0
df['is_verified'] = df['is_verified'].map({'yes': 1, 'no': 0})
df.head()
# Out:
#    retailer_id retailer_name retailer_sku           UPC Model Number  \
# 0            1    Amazon.com   B0735Q681B  7.544650e+11  70907205419
# 1            1    Amazon.com   B00WX0RJVS  8.858930e+11      2076438
# 2            1    Amazon.com   B004TTXA3W  8.911520e+11      2076453
# 3            1    Amazon.com   B007ZLL2LS           NaN         7512
# 4            1    Amazon.com   B004TTXA3W  8.911520e+11      2076453
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
# 2  SKYN Polyisoprene Large Condoms  Natural, 12 C...  SKYN  Sexual Wellness
# 3  SKYN Elite Extra Lube – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 4  SKYN Polyisoprene Large Condoms  Natural, 12 C...  SKYN  Sexual Wellness
#
#   Subcategory  week_id  ... review_date       review_id review_stars  \
# 0     Condoms   202245  ...  11/12/2022  R3A94R1G39RSYD            5
# 1     Condoms   202245  ...  11/12/2022  R2MBHRRN9LP4VS            5
# 2     Condoms   202245  ...  11/12/2022  R1QSDLGH59FSR9            5
# 3     Condoms   202245  ...  11/12/2022  R2SFPAKO9OGGGJ            5
# 4     Condoms   202245  ...  11/11/2022  R2KQG6C61RGXBD            4
#
#    is_verified  has_response  \
# 0            1            no
# 1            1            no
# 2            1            no
# 3            1            no
# 4            1            no
#
#                                          review_text  \
# 0   Pretty good rubbers. Great for pounding  and ...
# 1   They are good  out of the whole box i did hav...
# 2   My kids use my Amazon account and my junior i...
# 3   What can I say keeps me protected lol. Will d...
# 4   Medium-Large but not extra large. Rolls on sm...
#
#                             review_title  \
# 0                          Good Rubbers
# 1                         They are good
# 2   Son from college vouches for these!
# 3                              Works...
# 4                               Perfect
#
#                                          reviews_url                 Reviewer  \
# 0  https://www.amazon.com/gp/customer-reviews/R3A...                 Fat Dabs
# 1  https://www.amazon.com/gp/customer-reviews/R2M...  Roberto coronado medina
# 2  https://www.amazon.com/gp/customer-reviews/R1Q...               Maia Marie
# 3  https://www.amazon.com/gp/customer-reviews/R2S...                  R. Fell
# 4  https://www.amazon.com/gp/customer-reviews/R2K...          Amazon Customer
#
#                                        combined_text
# 0   Pretty good rubbers. Great for pounding  and ...
# 1   They are good  out of the whole box i did hav...
# 2   My kids use my Amazon account and my junior i...
# 3   What can I say keeps me protected lol. Will d...
# 4   Medium-Large but not extra large. Rolls on sm...
#
# [5 rows x 21 columns]

# %% [markdown]
# # CLEAN DATASET

# %%
#check for missing values
df.isnull().sum()
# Out:
# retailer_id        0
# retailer_name      0
# retailer_sku       0
# UPC              258
# Model Number     161
# Title              0
# Brand              0
# Category           0
# Subcategory        0
# week_id            0
# week_ending        0
# review_date        0
# review_id          0
# review_stars       0
# is_verified        0
# has_response       0
# review_text        5
# review_title       0
# reviews_url        0
# Reviewer           0
# combined_text      5
# dtype: int64

# %%
#UPC & Model Number are not relevent to the analysis, so we can drop those columns
df.drop(['UPC', 'Model Number'], axis=1, inplace=True)

# %%
#There are 5 rows with missing reviews, so they should be dropped from the dataset
df.dropna(inplace = True)

# %%
#confirm there are no null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column retailer_id has 0 null values
# Column retailer_name has 0 null values
# Column retailer_sku has 0 null values
# Column Title has 0 null values
# Column Brand has 0 null values
# Column Category has 0 null values
# Column Subcategory has 0 null values
# Column week_id has 0 null values
# Column week_ending has 0 null values
# Column review_date has 0 null values
# Column review_id has 0 null values
# Column review_stars has 0 null values
# Column is_verified has 0 null values
# Column has_response has 0 null values
# Column review_text has 0 null values
# Column review_title has 0 null values
# Column reviews_url has 0 null values
# Column Reviewer has 0 null values
# Column combined_text has 0 null values

# %%
#check for duplicates
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
#check unique ratings
df['review_stars'].value_counts()
# Out:
# 5    758
# 1    204
# 4    105
# 3     92
# 2     70
# Name: review_stars, dtype: int64

# %%
#create a target column based on review stars
df['target']=[0  if x<=3 else 1 for x in df['review_stars']]
df.head(2)
# Out:
#    retailer_id retailer_name retailer_sku  \
# 0            1    Amazon.com   B0735Q681B
# 1            1    Amazon.com   B00WX0RJVS
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
#
#   Subcategory  week_id week_ending review_date       review_id  review_stars  \
# 0     Condoms   202245  11/12/2022  11/12/2022  R3A94R1G39RSYD             5
# 1     Condoms   202245  11/12/2022  11/12/2022  R2MBHRRN9LP4VS             5
#
#    is_verified has_response  \
# 0            1           no
# 1            1           no
#
#                                          review_text     review_title  \
# 0   Pretty good rubbers. Great for pounding  and ...    Good Rubbers
# 1   They are good  out of the whole box i did hav...   They are good
#
#                                          reviews_url                 Reviewer  \
# 0  https://www.amazon.com/gp/customer-reviews/R3A...                 Fat Dabs
# 1  https://www.amazon.com/gp/customer-reviews/R2M...  Roberto coronado medina
#
#                                        combined_text  target
# 0   Pretty good rubbers. Great for pounding  and ...       1
# 1   They are good  out of the whole box i did hav...       1

# %%
df.to_csv('Resources/tableau_df.csv', index=False)

# %%
stopword_list = stopwords.words('english')
stopword_list += list(string.punctuation)
stopword_list += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘',"'",
'said',"'s", "also",'one',":(",'com', '!', '-', '–', '?', '_',"/",'condom','skyn', 'wife','well','box','great','use',
'woman','like',"n't",'u','el','ye','yet', 'use','kid', 'brand','m√≠','esposa','la','encanta', 'y','los','volvere',
'comprar']
stopword_set = set(stopword_list)

# tokenization
def process_review(review):
    tokens = nltk.word_tokenize(review)
    stopwords_removed = [token.lower() for token in tokens if token.lower() not in stopword_list]
    return stopwords_removed

# Stemming
from nltk.stem import PorterStemmer
ps = PorterStemmer()
# create a function stemming() and loop through each word in a review
def stemming(review):
    stemmed_review=[]
    for w in review:
        stemmed_review.append(ps.stem(w))
    return stemmed_review

# import libraries
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# create a function  and loop through each word in  a review
def lemmatization(review):
    lemma_list=[]
    for word in review:
        lemma_word=lemmatizer.lemmatize(word,pos='v') 
        lemma_list.append(lemma_word)
    return lemma_list

# Combine ll functions above and obtian cleaned text data 
def data_preprocessing(review):
    #tokenization, stop words removal, punctuation marks removel
    processed_review=list(map(process_review,review))
    # stemming
    stemming_reviews=list(map(stemming,processed_review))
    # lemmatization
    lemma_reviews=list(map(lemmatization,stemming_reviews))
    return lemma_reviews

cleaned_text_data=data_preprocessing(df['combined_text'])

# %%
df.head(2)
# Out:
#    retailer_id retailer_name retailer_sku  \
# 0            1    Amazon.com   B0735Q681B
# 1            1    Amazon.com   B00WX0RJVS
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
#
#   Subcategory  week_id week_ending review_date       review_id  review_stars  \
# 0     Condoms   202245  11/12/2022  11/12/2022  R3A94R1G39RSYD             5
# 1     Condoms   202245  11/12/2022  11/12/2022  R2MBHRRN9LP4VS             5
#
#    is_verified has_response  \
# 0            1           no
# 1            1           no
#
#                                          review_text     review_title  \
# 0   Pretty good rubbers. Great for pounding  and ...    Good Rubbers
# 1   They are good  out of the whole box i did hav...   They are good
#
#                                          reviews_url                 Reviewer  \
# 0  https://www.amazon.com/gp/customer-reviews/R3A...                 Fat Dabs
# 1  https://www.amazon.com/gp/customer-reviews/R2M...  Roberto coronado medina
#
#                                        combined_text  target
# 0   Pretty good rubbers. Great for pounding  and ...       1
# 1   They are good  out of the whole box i did hav...       1

# %%
#Combine all functions above and obtian cleaned text data 
def data_preprocessing(review):
    #tokenization, stop words removal, punctuation marks removel
    processed_review=list(map(process_review,review))
    # stemming
    stemming_reviews=list(map(stemming,processed_review))
    # lemmatization
    lemma_reviews=list(map(lemmatization,stemming_reviews))
    return lemma_reviews

# %%
cleaned_text_data=data_preprocessing(df['combined_text'])

# %%
df.head()
# Out:
#    retailer_id retailer_name retailer_sku  \
# 0            1    Amazon.com   B0735Q681B
# 1            1    Amazon.com   B00WX0RJVS
# 2            1    Amazon.com   B004TTXA3W
# 3            1    Amazon.com   B007ZLL2LS
# 4            1    Amazon.com   B004TTXA3W
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
# 2  SKYN Polyisoprene Large Condoms  Natural, 12 C...  SKYN  Sexual Wellness
# 3  SKYN Elite Extra Lube – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 4  SKYN Polyisoprene Large Condoms  Natural, 12 C...  SKYN  Sexual Wellness
#
#   Subcategory  week_id week_ending review_date       review_id  review_stars  \
# 0     Condoms   202245  11/12/2022  11/12/2022  R3A94R1G39RSYD             5
# 1     Condoms   202245  11/12/2022  11/12/2022  R2MBHRRN9LP4VS             5
# 2     Condoms   202245  11/12/2022  11/12/2022  R1QSDLGH59FSR9             5
# 3     Condoms   202245  11/12/2022  11/12/2022  R2SFPAKO9OGGGJ             5
# 4     Condoms   202245  11/12/2022  11/11/2022  R2KQG6C61RGXBD             4
#
#    is_verified has_response  \
# 0            1           no
# 1            1           no
# 2            1           no
# 3            1           no
# 4            1           no
#
#                                          review_text  \
# 0   Pretty good rubbers. Great for pounding  and ...
# 1   They are good  out of the whole box i did hav...
# 2   My kids use my Amazon account and my junior i...
# 3   What can I say keeps me protected lol. Will d...
# 4   Medium-Large but not extra large. Rolls on sm...
#
#                             review_title  \
# 0                          Good Rubbers
# 1                         They are good
# 2   Son from college vouches for these!
# 3                              Works...
# 4                               Perfect
#
#                                          reviews_url                 Reviewer  \
# 0  https://www.amazon.com/gp/customer-reviews/R3A...                 Fat Dabs
# 1  https://www.amazon.com/gp/customer-reviews/R2M...  Roberto coronado medina
# 2  https://www.amazon.com/gp/customer-reviews/R1Q...               Maia Marie
# 3  https://www.amazon.com/gp/customer-reviews/R2S...                  R. Fell
# 4  https://www.amazon.com/gp/customer-reviews/R2K...          Amazon Customer
#
#                                        combined_text  target
# 0   Pretty good rubbers. Great for pounding  and ...       1
# 1   They are good  out of the whole box i did hav...       1
# 2   My kids use my Amazon account and my junior i...       1
# 3   What can I say keeps me protected lol. Will d...       1
# 4   Medium-Large but not extra large. Rolls on sm...       1

# %%
# create two  new columns one for review_breakout , one for review length
df['review_breakout']=cleaned_text_data
df['review_length']=[len(x) for x in df['review_breakout']]

# %%
df.head()
# Out:
#    retailer_id retailer_name retailer_sku  \
# 0            1    Amazon.com   B0735Q681B
# 1            1    Amazon.com   B00WX0RJVS
# 2            1    Amazon.com   B004TTXA3W
# 3            1    Amazon.com   B007ZLL2LS
# 4            1    Amazon.com   B004TTXA3W
#
#                                                Title Brand         Category  \
# 0  SKYN Elite – 36 Count – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 1           SKYN Elite Condoms  10 Count (Pack of 1)  SKYN  Sexual Wellness
# 2  SKYN Polyisoprene Large Condoms  Natural, 12 C...  SKYN  Sexual Wellness
# 3  SKYN Elite Extra Lube – Ultra-Thin  Lubricated...  SKYN  Sexual Wellness
# 4  SKYN Polyisoprene Large Condoms  Natural, 12 C...  SKYN  Sexual Wellness
#
#   Subcategory  week_id week_ending review_date  ... is_verified  has_response  \
# 0     Condoms   202245  11/12/2022  11/12/2022  ...           1            no
# 1     Condoms   202245  11/12/2022  11/12/2022  ...           1            no
# 2     Condoms   202245  11/12/2022  11/12/2022  ...           1            no
# 3     Condoms   202245  11/12/2022  11/12/2022  ...           1            no
# 4     Condoms   202245  11/12/2022  11/11/2022  ...           1            no
#
#                                          review_text  \
# 0   Pretty good rubbers. Great for pounding  and ...
# 1   They are good  out of the whole box i did hav...
# 2   My kids use my Amazon account and my junior i...
# 3   What can I say keeps me protected lol. Will d...
# 4   Medium-Large but not extra large. Rolls on sm...
#
#                             review_title  \
# 0                          Good Rubbers
# 1                         They are good
# 2   Son from college vouches for these!
# 3                              Works...
# 4                               Perfect
#
#                                          reviews_url                 Reviewer  \
# 0  https://www.amazon.com/gp/customer-reviews/R3A...                 Fat Dabs
# 1  https://www.amazon.com/gp/customer-reviews/R2M...  Roberto coronado medina
# 2  https://www.amazon.com/gp/customer-reviews/R1Q...               Maia Marie
# 3  https://www.amazon.com/gp/customer-reviews/R2S...                  R. Fell
# 4  https://www.amazon.com/gp/customer-reviews/R2K...          Amazon Customer
#
#                                        combined_text target  \
# 0   Pretty good rubbers. Great for pounding  and ...      1
# 1   They are good  out of the whole box i did hav...      1
# 2   My kids use my Amazon account and my junior i...      1
# 3   What can I say keeps me protected lol. Will d...      1
# 4   Medium-Large but not extra large. Rolls on sm...      1
#
#                                      review_breakout  review_length
# 0  [pretti, good, rubber, pound, kind, posit, fee...             11
# 1                      [good, whole, two, rip, good]              5
# 2  [kid, amazon, account, junior, colleg, text, g...             33
# 3  [say, keep, protect, lol, definit, buy, worri,...             10
# 4  [medium-larg, extra, larg, roll, smoothli, eve...              8
#
# [5 rows x 22 columns]

# %%
df.to_csv('Resources/machine_learning.csv', index=False)
